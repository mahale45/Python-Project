# %%
print('Welcome to HDFC Bank')
password=int(input('Enter your password 4 digit'))
balance=25000
if password==1234:
    print('1.Withdraw\n2.Balance Enquiry\n3.Fast withdrawal\n4.cancel')
    menu=int(input('enter your choice'))
    if menu==1:
        withdraw_amount=int(input('enter amount to withdraw'))
        if (withdraw_amount<=balance):
            print('please take your cash')
            print('---------------------------------')
            print('Do want to know your balance')
            print('1.Yes\n2.No')
            a=int(input('enter your choice'))
            if a==1:
                print(balance-withdraw_amount)
                print('Thank You for banking with us')
            else:
                print('Thank You to banking with us')
        else:
            print('insuffiecient funds')
    elif menu ==2:
        print(balance)
        print('Thank You to banking with us')
    elif menu ==3:
        print('1.withdraw 5000\n2.withdraw 10000\n3.withdraw 15000\n4.withdraw 20000')
        fw=int(input('enter your choice'))
        if fw==1:
            print('withdraw 5000')
            print('please take your cash')
            print('---------------------------------')
            print('Do want to know your balance')
            print('1.Yes\n2.No')
            a=int(input('enter your choice'))
            if a==1:
                print(balance-5000)
                print('Thank You for banking with us')
            else:
                print('Thank You for banking with us')
        elif fw==2:
            print('withdraw 10000')
            print('please take your cash')
            print('---------------------------------')
            print('Do want to know your balance')
            print('1.Yes\n2.No')
            a=int(input('enter your choice'))
            if a==1:
                print(balance-10000)
                print('Thank You for banking with us')
            else:
                print('Thank You for banking with us') 
        elif fw==3:
            print('withdraw 15000')
            print('please take your cash')
            print('---------------------------------')
            print('Do want to know your balance')
            print('1.Yes\n2.No')
            a=int(input('enter your choice'))
            if a==1:
                print(balance-15000)
                print('Thank You for banking with us')
            else:
                print('Thank You for banking with us')  
                
        elif fw==4:
            print('withdraw 20000')
            print('please take your cash')
            print('---------------------------------')
            print('Do want to know your balance')
            print('1.Yes\n2.No')
            a=int(input('enter your choice'))
            if a==1:
                print(balance-20000)
                print('Thank You for banking with us')
            else:
                print('Thank You for banking with us')        
        else:
            print('Invalid choice')
    elif menu ==4:
        print('cancling the Process')
        
else:
    print('Password is incorrect')
# Out:
# Welcome to HDFC Bank
# Enter your password 4 digit1234
# 1.Withdraw
# 2.Balance Enquiry
# 3.Fast withdrawal
# 4.cancel
# enter your choice1
# enter amount to withdraw500
# please take your cash
# ---------------------------------
# Do want to know your balance
# 1.Yes
# 2.No
# enter your choice1
# 24500
# Thank You for banking with us
